# %%
# %load_ext autoreload
# %autoreload 2

# %%
import openktn as okn

# %%
net = okn.kinetic_transition_network(form='pandas.MicrostatesDataFrame')

# %%
okn.add_microstate(net, index=20)

# %%
okn.add_microstate(net, name='patata', index=10)

# %%
net
# Out:
#     index    name  weight  probability  component_index  basin_index  \
# 0     0.0     NaN     0.0          0.0              NaN          NaN
# 1     1.0     NaN     0.0          0.0              NaN          NaN
# 2     2.0     NaN     0.0          0.0              NaN          NaN
# 3     3.0     NaN     0.0          0.0              NaN          NaN
# 4     4.0     NaN     0.0          0.0              NaN          NaN
# 5     5.0     NaN     0.0          0.0              NaN          NaN
# 6     6.0     NaN     0.0          0.0              NaN          NaN
# 7     7.0     NaN     0.0          0.0              NaN          NaN
# 8     8.0     NaN     0.0          0.0              NaN          NaN
# 9     9.0     NaN     0.0          0.0              NaN          NaN
# 10   10.0  patata     0.0          0.0              NaN          NaN
# 11   11.0     NaN     0.0          0.0              NaN          NaN
# 12   12.0     NaN     0.0          0.0              NaN          NaN
# 13   13.0     NaN     0.0          0.0              NaN          NaN
# 14   14.0     NaN     0.0          0.0              NaN          NaN
# 15   15.0     NaN     0.0          0.0              NaN          NaN
# 16   16.0     NaN     0.0          0.0              NaN          NaN
# 17   17.0     NaN     0.0          0.0              NaN          NaN
# 18   18.0     NaN     0.0          0.0              NaN          NaN
# 19   19.0     NaN     0.0          0.0              NaN          NaN
# 20   20.0     NaN     0.0          0.0              NaN          NaN
#
#    coordinates color size
# 0          NaN   NaN  NaN
# 1          NaN   NaN  NaN
# 2          NaN   NaN  NaN
# 3          NaN   NaN  NaN
# 4          NaN   NaN  NaN
# 5          NaN   NaN  NaN
# 6          NaN   NaN  NaN
# 7          NaN   NaN  NaN
# 8          NaN   NaN  NaN
# 9          NaN   NaN  NaN
# 10         NaN   NaN  NaN
# 11         NaN   NaN  NaN
# 12         NaN   NaN  NaN
# 13         NaN   NaN  NaN
# 14         NaN   NaN  NaN
# 15         NaN   NaN  NaN
# 16         NaN   NaN  NaN
# 17         NaN   NaN  NaN
# 18         NaN   NaN  NaN
# 19         NaN   NaN  NaN
# 20         NaN   NaN  NaN

# %%
okn.microstate_in(net, name='patata')
# Out:
# True

# %%
df=pd.DataFrame(columns=['origin_index', 'end_index', 'weight', 'probability'])

# %%
df=df.append({'origin_index':2, 'end_index':1, 'weight':10, 'probability':0.0}, ignore_index=True)
df=df.append({'origin_index':2, 'end_index':2, 'weight':20, 'probability':0.0}, ignore_index=True)
df=df.append({'origin_index':1, 'end_index':2, 'weight':1, 'probability':0.0}, ignore_index=True)
df=df.append({'origin_index':4, 'end_index':1, 'weight':4, 'probability':0.0}, ignore_index=True)
df=df.append({'origin_index':7, 'end_index':2, 'weight':8, 'probability':0.0}, ignore_index=True)

# %%
df

# %%
aux=df.groupby(by='origin_index')['end_index'].count()

# %%
np.array(aux.keys())

# %%
import numpy as np

# %%
np.array(aux)

# %%
for ii,jj in aa.items():
    print(ii,jj)

# %%
df['origin_index'].isin([2]).sum()

# %%
df['probability']=df['weight'countgroupby(by='origin_index')['weight'].transform('sum')

# %%
df

# %%
for origin_index, end_index, weight in zip(df['origin_index'], df['end_index'], df['weight']):
    weight=99.0
